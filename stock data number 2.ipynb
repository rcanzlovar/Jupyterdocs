# %%
import pandas as pd
import pandas_datareader as pdr
#from pandas.util.testing import assert_frame_equal
import datetime
# %matplotlib inline
amc = pdr.get_data_yahoo('AMC', 
                          start='2019-1-1',
                          end='2020-5-12')
amc.plot()

# %%
print (amc)
# Out:
#              High    Low   Open  Close       Volume  Adj Close
# Date
# 2019-01-02  13.08  11.90  12.01  12.89    1374900.0  11.914326
# 2019-01-03  13.54  12.63  12.80  13.06    1392400.0  12.071457
# 2019-01-04  13.69  13.02  13.22  13.54    1025000.0  12.515124
# 2019-01-07  14.26  13.37  13.55  14.12    1119200.0  13.051224
# 2019-01-08  14.70  14.09  14.21  14.57    1122700.0  13.467159
# ...           ...    ...    ...    ...          ...        ...
# 2020-05-05   4.69   3.81   4.67   3.89    7504500.0   3.890000
# 2020-05-06   4.10   3.83   4.08   3.92    3105700.0   3.920000
# 2020-05-07   4.18   3.95   4.01   3.99    4105800.0   3.990000
# 2020-05-08   4.22   4.04   4.14   4.10    3571200.0   4.100000
# 2020-05-11   6.41   4.89   6.40   5.32  104951330.0   5.320000
#
# [342 rows x 6 columns]
